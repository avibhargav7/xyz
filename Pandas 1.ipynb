# %%
import pandas as pd

# %%
df = pd.read_csv('addresses.csv')

# %%
df
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#0 - died
#1 - Survived

# %%
#first 5 dataset
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#first 10 dataset
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#last 5 dataset
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#last 10 dataset
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df.describe(include='all').T
# Out:
#              count unique                      top freq       mean  \
# PassengerId  891.0    NaN                      NaN  NaN      446.0
# Survived     891.0    NaN                      NaN  NaN   0.383838
# Pclass       891.0    NaN                      NaN  NaN   2.308642
# Name           891    891  Braund, Mr. Owen Harris    1        NaN
# Sex            891      2                     male  577        NaN
# Age          714.0    NaN                      NaN  NaN  29.699118
# SibSp        891.0    NaN                      NaN  NaN   0.523008
# Parch        891.0    NaN                      NaN  NaN   0.381594
# Ticket         891    681                   347082    7        NaN
# Fare         891.0    NaN                      NaN  NaN  32.204208
# Cabin          204    147                  B96 B98    4        NaN
# Embarked       889      3                        S  644        NaN
#
#                     std   min     25%      50%    75%       max
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Name','Sex','Ticket']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# ...

# %%
df[['Name','Sex','Ticket']].describe()
# Out:
#                            Name   Sex  Ticket
# count                       891   891     891
# unique                      891     2     681
# top     Braund, Mr. Owen Harris  male  347082
# freq                          1   577       7

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
#pandas series is almost equivalent to list

# %%
type(df['Fare'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes=='object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[(df['Survived']==0) & (df['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[(df['Survived']==0) & (df['Sex']=='male')].count()
# Out:
# PassengerId    468
# Survived       468
# Pclass         468
# Name           468
# Sex            468
# Age            360
# SibSp          468
# Parch          468
# Ticket         468
# Fare           468
# Cabin           62
# Embarked       468
# dtype: int64

# %%
len(df[(df['Survived']==0) & (df['Sex']=='male')])
# Out:
# 468

# %%
#this mean 468 male passengers were died

# %%
len(df[(df['Survived']==0) & (df['Sex']=='female')])
# Out:
# 81

# %%
#this mean 81 female passengers were died

# %%
#to check number of male and female
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
len(df[df['Sex']=='male'])
# Out:
# 577

# %%
len(df[df['Sex']=='female'])
# Out:
# 314

# %%
#male survived
len(df[(df['Survived']==1) & (df['Sex']=='male')])
# Out:
# 109

# %%
#female survived
len(df[(df['Survived']==1) & (df['Sex']=='female')])
# Out:
# 233

# %%
#maximum fare
max(df['Fare'])
# Out:
# 512.3292

# %%
df[df['Fare']== max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
df[df['Fare']== min(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
df['Cabin'].isnull()==False
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Cabin, Length: 891, dtype: bool

# %%
df[df['Cabin'].isnull()==False]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#create new column
df['new_col'] ='sudh'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#create duplicate column
df['Name_new']= df['Name']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# create new column and new column will be add of two column age and passerger_class
df['age_Pclass'] = df['Age']+df['Pclass']

# %%
df['age_Pclass']
# Out:
# 0      25.0
# 1      39.0
# 2      29.0
# 3      36.0
# 4      38.0
#        ...
# 886    29.0
# 887    20.0
# 888     NaN
# 889    27.0
# 890    35.0
# Name: age_Pclass, Length: 891, dtype: float64

# %%
#delete columns
#df.drop('new_col')
#create error beacause we have not defined axis
#"['new_col'] not found in axis"

# %%
df.drop('new_col',axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('new_col',axis=1,inplace=True)

# %%
df.drop(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name_new       Cumings, Mrs. John Bradley (Florence Briggs Th...
# age_Pclass                                                  39.0
# Name: 1, dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
df.loc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name_new       Braund, Mr. Owen Harris
# age_Pclass                        25.0
# Name: 0, dtype: object

# %%
# iloc means inbuild
# loc means names

# %%
#wherever u are trying to call  iloc its simply mean it always go after inbulid index

# %%
#iloc always go after the interal indexing or default indexing

# %%
#loc go after name indexes

# %%
#both are trying to fectch records from dataset

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[2:5]     #start from 2 to 5
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked  \
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q
#
#                                        Name_new  age_Pclass
# 2                        Heikkinen, Miss. Laina        29.0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)        36.0
# ...

# %%
df.loc[101:106,['Survived','Pclass']]
# Out:
#      Survived  Pclass
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3
# 106         1       3

# %%
#try to fetch only some particular record

# %%
df.loc[3:5,['Fare','Cabin','Embarked']]
# Out:
#       Fare Cabin Embarked
# 3  53.1000  C123        S
# 4   8.0500   NaN        S
# 5   8.4583   NaN        Q

# %%
df.loc[[3,7],['Fare','Cabin','Embarked']]
# Out:
#      Fare Cabin Embarked
# 3  53.100  C123        S
# 7  21.075   NaN        S

# %%
df.iloc[[3,7],[9,10,11]]
# Out:
#       Fare Cabin Embarked
# 4   8.0500   NaN        S
# 8  11.1333   NaN        S

# %%
df.iloc[3:7,[9,10,11]]
# Out:
#       Fare Cabin Embarked
# 4   8.0500   NaN        S
# 5   8.4583   NaN        Q
# 6  51.8625   E46        S
# 7  21.0750   NaN        S

# %%
df.iloc[[3,5],[0,2]]
# Out:
#    PassengerId  Pclass
# 4            5       3
# 6            7       1

# %%
df.loc[[3,5],['PassengerId','Pclass']]
# Out:
#    PassengerId  Pclass
# 3            4       1
# 5            6       3

# %%
df[df['Age']>35]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1 = df.iloc[1:5,[2,3,4,5,9,10]]

# %%
df1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %%
#name of the row indexes

# %%
df1.set_index('Name')
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN
# Moran, Mr. James                               NaN

# %%
df1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %%
df1.set_index('Name',inplace=True)

# %%
df1
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN
# Moran, Mr. James                               NaN

# %%
#drop all of those records where we have null value

# %%
df1.dropna()  #bydefault row wise check null value
# Out:
#                                               Pclass     Sex   Age  Fare Cabin
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1  C123

# %%
df1.dropna(axis=1)  #bydefault column wise check null value
# Out:
#                                               Pclass     Sex     Fare
# Name
# Heikkinen, Miss. Laina                             3  female   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  53.1000
# Allen, Mr. William Henry                           3    male   8.0500
# Moran, Mr. James                                   3    male   8.4583

# %%
#differece between drop and dropna
#in drop it will drop entire row or entrire column
#in dropna it will check colmnn and row its has null value or not

# %%
#thresh means require that many non -NA values. cannot be combined with how.
# it will done nothing
#it requre atleast one non NA value
df1.dropna(axis=1, thresh=1)
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN
# Moran, Mr. James                               NaN

# %%
#it requre atleast two non NA value
df1.dropna(axis=1, thresh=2)
# Out:
#                                               Pclass     Sex   Age     Fare
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583

# %%
#it requre atleast three non NA value
df1.dropna(axis=1, thresh=3)
# Out:
#                                               Pclass     Sex   Age     Fare
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583

# %%
#it requre atleast four NA value
df1.dropna(axis=1, thresh=4)
# Out:
#                                               Pclass     Sex     Fare
# Name
# Heikkinen, Miss. Laina                             3  female   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  53.1000
# Allen, Mr. William Henry                           3    male   8.0500
# Moran, Mr. James                                   3    male   8.4583

# %%
#it requre atleast four NA value
df1.dropna(axis=0, thresh=4)
# Out:
#                                               Pclass     Sex   Age    Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.925
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.100
# Allen, Mr. William Henry                           3    male  35.0   8.050
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN

# %%
df1
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN
# Moran, Mr. James                               NaN

# %%
#we have a null value in Age column we have to fill with some other value

# %%
df1.fillna("avi")
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   avi   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         avi
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       avi
# Moran, Mr. James                               avi

# %%
df1.fillna(df1['Age'].mean())
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male  32.0   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                        32.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                      32.0
# Moran, Mr. James                              32.0

# %%
#how many record do we have in sex wise

# %%
df1.groupby('Sex').count()
# Out:
#         Pclass  Age  Fare  Cabin
# Sex
# female       2    2     2      1
# male         2    1     2      0

# %%
df1.groupby('Sex').mean()
# Out:
#         Pclass   Age      Fare
# Sex
# female     2.0  30.5  30.51250
# male       3.0  35.0   8.25415

# %%
df1.groupby('Sex').mean()['Age']
# Out:
# Sex
# female    30.5
# male      35.0
# Name: Age, dtype: float64

# %%
#how many revenue im able to generate from male and female

# %%
df1.groupby('Sex').sum()['Fare']
# Out:
# Sex
# female    61.0250
# male      16.5083
# Name: Fare, dtype: float64

# %%
df1
# Out:
# Name
# Heikkinen, Miss. Laina                          1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)    0.333333
# Allen, Mr. William Henry                        1.000000
# Moran, Mr. James                                1.000000
# Name: Pclass, dtype: float64

# %%
df2 = df.iloc[0:4,0:4]

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %%
#merger operation

# %%
pd.concat([df1,df2])  #bydefault row wise
#merge dataset horizontally
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
# 1                                                  1     NaN   NaN      NaN
# 2                                                  3     NaN   NaN      NaN
# 3                                                  1     NaN   NaN      NaN
# 4                                                  3     NaN   NaN      NaN
#
#                                              Cabin  PassengerId  Survived  \
# Heikkinen, Miss. Laina                         NaN          NaN       NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123          NaN       NaN
# ...

# %%
pd.concat([df1,df2],axis=1)  #merge dataset vertically
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Heikkinen, Miss. Laina                           3.0  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)     1.0  female  35.0  53.1000
# Allen, Mr. William Henry                         3.0    male  35.0   8.0500
# Moran, Mr. James                                 3.0    male   NaN   8.4583
# 1                                                NaN     NaN   NaN      NaN
# 2                                                NaN     NaN   NaN      NaN
# 3                                                NaN     NaN   NaN      NaN
# 4                                                NaN     NaN   NaN      NaN
#
#                                              Cabin  PassengerId  Survived  \
# Heikkinen, Miss. Laina                         NaN          NaN       NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123          NaN       NaN
# ...

# %%
df2['new1']=df2['Pclass'].apply(lambda x : x/3)

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  len_name      new1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        51  0.333333
# 2                             Heikkinen, Miss. Laina        22  1.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)        44  0.333333
# 4                           Allen, Mr. William Henry        24  1.000000

# %%
df2['len_name']= df2['Name'].apply(len)

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  len_name      new1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        51  0.333333
# 2                             Heikkinen, Miss. Laina        22  1.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)        44  0.333333
# 4                           Allen, Mr. William Henry        24  1.000000

# %%
#wherever a passenger id < 3 data as it is
#wherever a passergerid >=3

# %%
import math
def cust1(x):
    if x<3:
        return x
    else:
        return math.log10(x)

# %%
df2['PassengerId_filter']= df2['PassengerId'].apply(cust1)

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  len_name      new1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        51  0.333333
# 2                             Heikkinen, Miss. Laina        22  1.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)        44  0.333333
# 4                           Allen, Mr. William Henry        24  1.000000
#
#    PassengerId_filter
# 1            2.000000
# 2            0.477121
# 3            0.602060
# 4            0.698970

# %%
def test2(x):
    if x=='female':
        return 1
    else:
        return 0

# %%
df2['Sex_filter']=df2['Sex'].apply(test2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1
# Out:
# Name
# Heikkinen, Miss. Laina                          1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)    0.333333
# Allen, Mr. William Henry                        1.000000
# Moran, Mr. James                                1.000000
# Name: Pclass, dtype: float64

# %%
def test3(x):
    if x <= 100:
        return "A"
    elif x>100 and x<200:
        return "B"
    else:
        return "C"

# %%
df['Fare_group'] = df['Fare'].apply(test3)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...
